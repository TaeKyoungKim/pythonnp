# %% [markdown]
# ### requests.request(method, url, **kwargs)
# ### requests.<http_method>(url, params=None, **kwargs)

# %%
import requests
requests.request("get" ,"http://naver.com" )
# Out:
# <Response [200]>

# %%
resp = requests.get("http://google.com")

# %%
resp
# Out:
# <Response [200]>

# %%
resp = requests.get("https://search.naver.com", params={'query':  '무역전쟁'})
resp.json
# Out:
# <bound method Response.json of <Response [200]>>

# %%
print(resp.encoding)
print(resp.status_code)
print(resp.headers)
print(resp.url)
# Out:
# UTF-8
# 200
# {'Date': 'Sat, 22 Jun 2019 17:07:31 GMT', 'Content-Type': 'text/html; charset=UTF-8', 'Content-Length': '99', 'Connection': 'keep-alive', 'Last-Modified': 'Thu, 20 Jun 2019 03:58:13 GMT', 'ETag': '"5a-58bb95ad9ff40-gzip"', 'Accept-Ranges': 'bytes', 'Vary': 'Accept-Encoding', 'Content-Encoding': 'gzip', 'Server': 'nxg'}
# https://search.naver.com/?query=%EB%AC%B4%EC%97%AD%EC%A0%84%EC%9F%81

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### soup = BeautifulSoup(markup=‘’, features=None)
# ![image.png](attachment:image.png)

# %%
resp = requests.get("http://naver.com")
soup = BeautifulSoup(resp.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html lang="ko">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="origin" name="Referrer"/>
#   <meta content="text/javascript" http-equiv="Content-Script-Type"/>
#   <meta content="text/css" http-equiv="Content-Style-Type"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=1100" name="viewport"/>
#   <meta content="NAVER" name="apple-mobile-web-app-title">
#    <meta content="index,nofollow" name="robots">
#     <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="description">
#      <meta content="네이버" property="og:title"/>
#      <meta content="https://www.naver.com/" property="og:url"/>
#      <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" property="og:image"/>
#      <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" property="og:description">
#       <meta content="summary" name="twitter:card"/>
#       <meta content="" name="twitter:title"/>
# ...

# %%
resp1 = requests.get("http://google.com")
soup1 = BeautifulSoup(resp1.content, 'html.parser')
print(soup1.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html itemscope="" itemtype="http://schema.org/WebPage" lang="ko">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/>
#   <title>
#    Google
#   </title>
#   <script nonce="xVlxdZo89TqiedI5Qa598A==">
# ...

# %% [markdown]
# ### soup.<tag_name>
#
# #### soup.<tag_name> - 태그 이름으로 접근
# #### soup.<tag_name>.attrs - 태그의 속성 접근
# #### find_all(), find()
# #### soup.find(‘<태그이름>’, ‘속성’) - 태그 찾기 (가장 빠른 한 개)
# #### soup.find_all(‘<태그이름>’, ‘속성’) - 태그 찾기 (전체 - list)

# %%
resp = requests.get("http://naver.com")
soup = BeautifulSoup(resp.content, 'html.parser')
soup.span
# Out:
# <span>연합뉴스 바로가기</span>

# %%
soup.span.attrs
# Out:
# {}

# %%
soup.find_all()
# Out:
# [<html lang="ko">
#  <head>
#  <meta charset="utf-8"/>
#  <meta content="origin" name="Referrer"/>
#  <meta content="text/javascript" http-equiv="Content-Script-Type"/>
#  <meta content="text/css" http-equiv="Content-Style-Type"/>
#  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#  <meta content="width=1100" name="viewport"/>
#  <meta content="NAVER" name="apple-mobile-web-app-title">
#  <meta content="index,nofollow" name="robots">
#  <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="description">
#  <meta content="네이버" property="og:title"/>
#  <meta content="https://www.naver.com/" property="og:url"/>
#  <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" property="og:image"/>
#  <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" property="og:description">
#  <meta content="summary" name="twitter:card"/>
#  <meta content="" name="twitter:title"/>
#  <meta content="https://www.naver.com/" name="twitter:url"/>
# ...

# %%
soup.find()
# Out:
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="origin" name="Referrer"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=1100" name="viewport"/>
# <meta content="NAVER" name="apple-mobile-web-app-title">
# <meta content="index,nofollow" name="robots">
# <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="description">
# <meta content="네이버" property="og:title"/>
# <meta content="https://www.naver.com/" property="og:url"/>
# <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" property="og:image"/>
# <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" property="og:description">
# <meta content="summary" name="twitter:card"/>
# <meta content="" name="twitter:title"/>
# <meta content="https://www.naver.com/" name="twitter:url"/>
# ...

# %%
soup.a.attrs
# Out:
# {'href': '#news_cast',
#  'onclick': "document.getElementById('news_cast2').tabIndex = -1;document.getElementById('news_cast2').focus();return false;"}

# %%
soup.find_all("metta", "content")
# Out:
# []

# %%
with open("index.html") as fp:
    soup = BeautifulSoup(fp, 'html.parser')
    all_divs = soup.find_all("p")
    print(all_divs)
# Out:
# [<p>a</p>, <p>b</p>, <p>c</p>, <p>d</p>, <p>e</p>, <p>f</p>, <p>g</p>, <p>h</p>, <p>i</p>, <p>This is a paragraph.</p>, <p>This is another paragraph.</p>]

# %%
soup.body.next_sibling
# Out:
# '\n'

# %%
soup.p.previous_sibling
# Out:
# '\n'

# %% [markdown]
# ### 형제 다루기
#
# #### BeautifulSoup의 next_siblings() 함수는 테이블에서 데이터를 쉽게 수집할 수 있으며, 특히 테이블에 타이틀 행이 있을 때 유용합니다.

# %%
from urllib.request import urlopen

from bs4 import BeautifulSoup

html = urlopen("http://www.pythonscraping.com/pages/page3.html")

 

bsObj = BeautifulSoup(html, "html.parser")
for sibling in bsObj.find("table",{"id":"giftList"}).tr.next_siblings:
    print(sibling)
# Out:
# <tr class="gift" id="gift1"><td>
# Vegetable Basket
# </td><td>
# This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
# <span class="excitingNote">Now with super-colorful bell peppers!</span>
# </td><td>
# $15.00
# </td><td>
# <img src="../img/gifts/img1.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift2"><td>
# Russian Nesting Dolls
# </td><td>
# Hand-painted by trained monkeys, these exquisite dolls are priceless! And by "priceless," we mean "extremely expensive"! <span class="excitingNote">8 entire dolls per set! Octuple the presents!</span>
# </td><td>
# $10,000.52
# </td><td>
# <img src="../img/gifts/img2.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift3"><td>
# Fish Painting
# </td><td>
# If something seems fishy about this painting, it's because it's a fish! <span class="excitingNote">Also hand-painted by trained monkeys!</span>
# </td><td>
# $10,005.00
# </td><td>
# <img src="../img/gifts/img3.jpg"/>
# </td></tr>
#
#
# ...

# %%
from urllib.request import urlopen

from bs4 import BeautifulSoup
with urlopen("http://naver.com") as fp:
    soup = BeautifulSoup(fp, 'html.parser')
    print(soup.prettify())
    all_divs = soup.find_all("p")
    print(all_divs)
# Out:
# <!DOCTYPE doctype html>
# <html lang="ko">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="origin" name="Referrer"/>
#   <meta content="text/javascript" http-equiv="Content-Script-Type"/>
#   <meta content="text/css" http-equiv="Content-Style-Type"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=1100" name="viewport"/>
#   <meta content="NAVER" name="apple-mobile-web-app-title">
#    <meta content="index,nofollow" name="robots">
#     <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="description">
#      <meta content="네이버" property="og:title"/>
#      <meta content="https://www.naver.com/" property="og:url"/>
#      <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" property="og:image"/>
#      <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" property="og:description">
#       <meta content="summary" name="twitter:card"/>
#       <meta content="" name="twitter:title"/>
# ...

# %%
from selenium import webdriver
import time

driver = webdriver.Chrome('C:\Users\modu\Documents\chromedriver_win32/chromedriver')
driver.implicitly_wait(3)
# Out:
#   File "<ipython-input-7-8d64b8911fab>", line 4
#     driver = webdriver.Chrome('C:\Users\modu\Documents\chromedriver_win32/chromedriver')
#                              ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
